# %%
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem.snowball import SnowballStemmer
import nltk
import re
import string
import numpy as np
import spacy
import pandas as pd
from fuzzywuzzy import fuzz
from nltk.corpus import stopwords
import heapq
import yaml
from nltk.stem import WordNetLemmatizer, PorterStemmer

from transformers import AutoTokenizer, AutoModelForSequenceClassification, AutoConfig
from scipy.special import softmax
import numpy as np
from array import array
import copy

nlp = spacy.load('en_core_web_lg')

df = pd.read_csv('./scraper/archive/javascript.csv', names=["POSTID", "POSTLINK", "POSTTITLE", "POSTBODY", "POSTDATE", "POSTVOTECOUNTS", "COMMENTID", "COMMENTSCORE", "COMMENTUSERNAME", "COMMENTTEXT", "COMMENTDATETIME", "ANSWERID", "ANSWERTEXT", "ANSWERBODY", "ANSWERDATETIME", "ANSWERVOTECOUNTS", "ANSWERCMTID", "ANSWERCMTTEXT", "ANSWERCMTBODY", "ANSWERCMTDATETIME", "ANSWERCMTVOTECOUNTS" , "TYPE"])

print(df.shape)
display(df.head())

print("\n")
print("All Columns DF")
df.columns
# Out:
# /Users/shaun/miniforge3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# (101724, 22)
#      POSTID                                           POSTLINK  \
# 0  76144358  https://stackoverflow.com/questions/76144358/i...
# 1  36280818  https://stackoverflow.com/questions/36280818/h...
# 2  36280818  https://stackoverflow.com/questions/36280818/h...
# 3  36280818  https://stackoverflow.com/questions/36280818/h...
# 4  36280818  https://stackoverflow.com/questions/36280818/h...
#
#                                            POSTTITLE  \
# 0  I'm creating a color blender using Adobe Anima...
# 1       How to convert file to base64 in JavaScript?
# 2       How to convert file to base64 in JavaScript?
# 3       How to convert file to base64 in JavaScript?
# 4       How to convert file to base64 in JavaScript?
#
#                                             POSTBODY  \
# 0  \n                \n<p>I'm using Adobe Animate...
# 1  \n                \n<p><strong>UPD</strong> Ty...
# 2  \n                \n<p><strong>UPD</strong> Ty...
# 3  \n                \n<p><strong>UPD</strong> Ty...
# 4  \n                \n<p><strong>UPD</strong> Ty...
#
#                     POSTDATE POSTVOTECOUNTS COMMENTID  COMMENTSCORE  \
# 0  ('2023-05-01 01:47:04Z',)        ('-1',)       NaN           NaN
# 1  ('2016-03-29 09:49:26Z',)       ('355',)       NaN           NaN
# 2  ('2016-03-29 09:49:26Z',)       ('355',)       NaN           NaN
# 3  ('2016-03-29 09:49:26Z',)       ('355',)       NaN           NaN
# 4  ('2016-03-29 09:49:26Z',)       ('355',)       NaN           NaN
#
#   COMMENTUSERNAME COMMENTTEXT  ...  \
# 0             NaN         NaN  ...
# 1             NaN         NaN  ...
# 2             NaN         NaN  ...
# 3             NaN         NaN  ...
# 4             NaN         NaN  ...
#
#                                           ANSWERTEXT  \
# 0                                                NaN
# 1                                                NaN
# 2  Try the solution using the FileReader class:\n...
# 3  Try the solution using the FileReader class:\n...
# 4  Try the solution using the FileReader class:\n...
#
#                                           ANSWERBODY  \
# 0                                                NaN
# 1                                                NaN
# 2  ('\n<p>Try the solution using the <code>FileRe...
# 3  ('\n<p>Try the solution using the <code>FileRe...
# 4  ('\n<p>Try the solution using the <code>FileRe...
#
#                                 ANSWERDATETIME ANSWERVOTECOUNTS  \
# 0                                          NaN              NaN
# 1                                          NaN              NaN
# 2  2017-06-09 19:16:52Z, License: CC BY-SA 3.0         ('429',)
# 3  2017-06-09 19:16:52Z, License: CC BY-SA 3.0         ('429',)
# 4  2017-06-09 19:16:52Z, License: CC BY-SA 3.0         ('429',)
#
#      ANSWERCMTID                                      ANSWERCMTTEXT  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3  ('75927236',)  read more about FileReader API: developer.mozi...
# 4  ('81338095',)  I tried to use return reader.result from the g...
#
#                                        ANSWERCMTBODY     ANSWERCMTDATETIME  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3  ('\n                \n                <span cl...  Jun 9, 2017 at 19:16
# 4  ('\n                \n                <span cl...   Nov 9, 2017 at 5:35
#
#   ANSWERCMTVOTECOUNTS            TYPE
# 0                 NaN            post
# 1                 NaN            post
# 2                 NaN          answer
# 3              ('3',)  answer_comment
# 4             ('20',)  answer_comment
#
# [5 rows x 22 columns]
# All Columns DF
# Index(['POSTID', 'POSTLINK', 'POSTTITLE', 'POSTBODY', 'POSTDATE',
#        'POSTVOTECOUNTS', 'COMMENTID', 'COMMENTSCORE', 'COMMENTUSERNAME',
#        'COMMENTTEXT', 'COMMENTDATETIME', 'ANSWERID', 'ANSWERTEXT',
#        'ANSWERBODY', 'ANSWERDATETIME', 'ANSWERVOTECOUNTS', 'ANSWERCMTID',
#        'ANSWERCMTTEXT', 'ANSWERCMTBODY', 'ANSWERCMTDATETIME',
#        'ANSWERCMTVOTECOUNTS', 'TYPE'],
#       dtype='object')

# %%
ALL_COLS = ["POSTID", "POSTLINK", "POSTTITLE", "POSTBODY", "POSTDATE", "POSTVOTECOUNTS", "COMMENTID", "COMMENTSCORE", "COMMENTUSERNAME", "COMMENTTEXT", "COMMENTDATETIME", "ANSWERID", "ANSWERTEXT", "ANSWERBODY", "ANSWERDATETIME", "ANSWERVOTECOUNTS", "ANSWERCMTID", "ANSWERCMTTEXT", "ANSWERCMTBODY", "ANSWERCMTDATETIME", "ANSWERCMTVOTECOUNTS" , "TYPE"]

dPOST  = pd.DataFrame(columns=ALL_COLS)
dPOST = df.copy();
dPOST = dPOST.drop(columns=['COMMENTID', 'COMMENTSCORE', 'COMMENTUSERNAME', 'COMMENTTEXT', 'COMMENTDATETIME', 'ANSWERID', 'ANSWERTEXT', 'ANSWERBODY', 'ANSWERDATETIME', 'ANSWERVOTECOUNTS', 'ANSWERCMTID', 'ANSWERCMTTEXT', 'ANSWERCMTBODY', 'ANSWERCMTDATETIME', 'ANSWERCMTVOTECOUNTS'])
# drop if type is not post
dPOST = dPOST[dPOST['TYPE'] == 'post']
display(dPOST.head(3))

dfPC = pd.DataFrame(columns=ALL_COLS)
dfPC = df.copy();
dfPC = dfPC.drop(columns=['ANSWERID', 'ANSWERTEXT', 'ANSWERBODY', 'ANSWERDATETIME', 'ANSWERVOTECOUNTS', 'ANSWERCMTID', 'ANSWERCMTTEXT', 'ANSWERCMTBODY', 'ANSWERCMTDATETIME', 'ANSWERCMTVOTECOUNTS'])
# drop if type is not post
dfPC = dfPC[dfPC['TYPE'] == 'post_comment']
display(dfPC.head(3))

dfA = pd.DataFrame(columns=ALL_COLS)
dfA = df.copy();
dfA = dfA.drop(columns=['POSTLINK', 'POSTBODY', 'POSTDATE', 'POSTVOTECOUNTS', 'COMMENTID', 'COMMENTSCORE', 'COMMENTUSERNAME', 'COMMENTTEXT', 'COMMENTDATETIME', 'ANSWERCMTID', 'ANSWERCMTTEXT', 'ANSWERCMTBODY', 'ANSWERCMTDATETIME', 'ANSWERCMTVOTECOUNTS'])

dfAAC = dfA[dfA['TYPE'] == 'answer']
display(dfAAC.head(3))

dFAC = pd.DataFrame(columns=ALL_COLS)
dFAC = df.copy();
dFAC = dFAC.drop(columns=['POSTLINK', 'POSTBODY', 'POSTDATE', 'POSTVOTECOUNTS', 'COMMENTID', 'COMMENTSCORE', 'COMMENTUSERNAME', 'COMMENTTEXT', 'COMMENTDATETIME', 'ANSWERTEXT', 'ANSWERBODY', 'ANSWERDATETIME', 'ANSWERVOTECOUNTS'])
dFACT = dFAC[dFAC['TYPE'] == 'answer_comment']
display(dFACT.head(3))

print("Post DF")
print(dPOST.columns)
print('\n')

print("Post Comment DF")
print(dfPC.columns)
print('\n')

print("Answer DF")
print(dfAAC.columns)
print('\n')

print("Answer Comment DF")
print(dFACT.columns)
print('\n')
# Out:
#       POSTID                                           POSTLINK  \
# 0   76144358  https://stackoverflow.com/questions/76144358/i...
# 1   36280818  https://stackoverflow.com/questions/36280818/h...
# 35  76143948  https://stackoverflow.com/questions/76143948/r...
#
#                                             POSTTITLE  \
# 0   I'm creating a color blender using Adobe Anima...
# 1        How to convert file to base64 in JavaScript?
# 35                    Resize with JavaScript (JQuery)
#
#                                              POSTBODY  \
# 0   \n                \n<p>I'm using Adobe Animate...
# 1   \n                \n<p><strong>UPD</strong> Ty...
# 35  \n                \n<p>I want to resize multip...
#
#                      POSTDATE POSTVOTECOUNTS  TYPE
# 0   ('2023-05-01 01:47:04Z',)        ('-1',)  post
# 1   ('2016-03-29 09:49:26Z',)       ('355',)  post
# 35  ('2023-04-30 23:07:53Z',)         ('1',)  post
#       POSTID                                           POSTLINK  \
# 36  76143948  https://stackoverflow.com/questions/76143948/r...
# 43  76144135  https://stackoverflow.com/questions/76144135/j...
# 44  76144135  https://stackoverflow.com/questions/76144135/j...
#
#                                             POSTTITLE  \
# 36                    Resize with JavaScript (JQuery)
# 43  JavaScript Rock Paper Scissors Game, alert fun...
# 44  JavaScript Rock Paper Scissors Game, alert fun...
#
#                                              POSTBODY  \
# 36  \n                \n<p>I want to resize multip...
# 43  \n                \n<p>I am attempting to make...
# 44  \n                \n<p>I am attempting to make...
#
#                      POSTDATE POSTVOTECOUNTS          COMMENTID  COMMENTSCORE  \
# 36  ('2023-04-30 23:07:53Z',)         ('1',)  comment-134283400           NaN
# 43  ('2023-05-01 00:14:46Z',)         ('1',)  comment-134283077           3.0
# 44  ('2023-05-01 00:14:46Z',)         ('1',)  comment-134283099           NaN
#
#    COMMENTUSERNAME                                        COMMENTTEXT  \
# 36        disinfor  I updated my answer a bit to give another exam...
# 43     Unmitigated  You need <code>let Humanity = 0; let AI = 0;</...
# 44         Orifjon           Did you check console for error message?
#
#                                 COMMENTDATETIME          TYPE
# 36  2023-05-01 01:21:53Z, License: CC BY-SA 4.0  post_comment
# 43  2023-05-01 00:17:01Z, License: CC BY-SA 4.0  post_comment
# 44  2023-05-01 00:18:57Z, License: CC BY-SA 4.0  post_comment
#       POSTID                                     POSTTITLE    ANSWERID  \
# 2   36280818  How to convert file to base64 in JavaScript?  36281449.0
# 8   36280818  How to convert file to base64 in JavaScript?  57272491.0
# 14  36280818  How to convert file to base64 in JavaScript?  46639837.0
#
#                                            ANSWERTEXT  \
# 2   Try the solution using the FileReader class:\n...
# 8   Modern ES6 way (async/await)\nconst toBase64 =...
# 14  If you're after a promise-based solution, this...
#
#                                            ANSWERBODY  \
# 2   ('\n<p>Try the solution using the <code>FileRe...
# 8   ('\n<p><strong>Modern ES6 way</strong> (async/...
# 14  ('\n<p>If you\'re after a promise-based soluti...
#
#                                  ANSWERDATETIME ANSWERVOTECOUNTS    TYPE
# 2   2017-06-09 19:16:52Z, License: CC BY-SA 3.0         ('429',)  answer
# 8   2020-02-20 00:30:24Z, License: CC BY-SA 4.0         ('400',)  answer
# 14  2018-04-26 08:16:38Z, License: CC BY-SA 3.0         ('161',)  answer
#      POSTID                                     POSTTITLE    ANSWERID  \
# 3  36280818  How to convert file to base64 in JavaScript?  36281449.0
# 4  36280818  How to convert file to base64 in JavaScript?  36281449.0
# 5  36280818  How to convert file to base64 in JavaScript?  36281449.0
#
#      ANSWERCMTID                                      ANSWERCMTTEXT  \
# 3  ('75927236',)  read more about FileReader API: developer.mozi...
# 4  ('81338095',)  I tried to use return reader.result from the g...
# 5  ('81381618',)  I made a question out of the above comment if ...
#
#                                        ANSWERCMTBODY     ANSWERCMTDATETIME  \
# 3  ('\n                \n                <span cl...  Jun 9, 2017 at 19:16
# 4  ('\n                \n                <span cl...   Nov 9, 2017 at 5:35
# 5  ('\n                \n                <span cl...  Nov 10, 2017 at 5:21
#
#   ANSWERCMTVOTECOUNTS            TYPE
# 3              ('3',)  answer_comment
# 4             ('20',)  answer_comment
# 5              ('2',)  answer_comment
# Post DF
# Index(['POSTID', 'POSTLINK', 'POSTTITLE', 'POSTBODY', 'POSTDATE',
#        'POSTVOTECOUNTS', 'TYPE'],
#       dtype='object')
#
#
# Post Comment DF
# Index(['POSTID', 'POSTLINK', 'POSTTITLE', 'POSTBODY', 'POSTDATE',
#        'POSTVOTECOUNTS', 'COMMENTID', 'COMMENTSCORE', 'COMMENTUSERNAME',
#        'COMMENTTEXT', 'COMMENTDATETIME', 'TYPE'],
#       dtype='object')
#
#
# Answer DF
# Index(['POSTID', 'POSTTITLE', 'ANSWERID', 'ANSWERTEXT', 'ANSWERBODY',
#        'ANSWERDATETIME', 'ANSWERVOTECOUNTS', 'TYPE'],
#       dtype='object')
#
#
# Answer Comment DF
# Index(['POSTID', 'POSTTITLE', 'ANSWERID', 'ANSWERCMTID', 'ANSWERCMTTEXT',
#        'ANSWERCMTBODY', 'ANSWERCMTDATETIME', 'ANSWERCMTVOTECOUNTS', 'TYPE'],
#       dtype='object')

# %% [markdown]
# # Explanatory Analysis

# %% [markdown]
# #### Clean out noisy values

# %%
import warnings
warnings.filterwarnings('ignore')

dPOST['POSTVOTECOUNTS'] = dPOST['POSTVOTECOUNTS'].str.replace(r"(", '')
dPOST['POSTVOTECOUNTS'] = dPOST['POSTVOTECOUNTS'].str.replace(r")", '')
dPOST['POSTVOTECOUNTS'] = dPOST['POSTVOTECOUNTS'].str.replace(r"'", '')
dPOST['POSTVOTECOUNTS'] = dPOST['POSTVOTECOUNTS'].str.replace(r",", '')

dPOST['POSTDATE'] = dPOST['POSTDATE'].str.replace(r"(", '')
dPOST['POSTDATE'] = dPOST['POSTDATE'].str.replace(r")", '')
dPOST['POSTDATE'] = dPOST['POSTDATE'].str.replace(r"'", '')
dPOST['POSTDATE'] = dPOST['POSTDATE'].str.replace(r",", '')
display(dPOST.head(1))

dfPC['POSTVOTECOUNTS'] = dfPC['POSTVOTECOUNTS'].str.replace(r"(", '')
dfPC['POSTVOTECOUNTS'] = dfPC['POSTVOTECOUNTS'].str.replace(r")", '')
dfPC['POSTVOTECOUNTS'] = dfPC['POSTVOTECOUNTS'].str.replace(r"'", '')
dfPC['POSTVOTECOUNTS'] = dfPC['POSTVOTECOUNTS'].str.replace(r",", '')

dfPC['POSTDATE'] = dfPC['POSTDATE'].str.replace(r"(", '')
dfPC['POSTDATE'] = dfPC['POSTDATE'].str.replace(r")", '')
dfPC['POSTDATE'] = dfPC['POSTDATE'].str.replace(r"'", '')
dfPC['POSTDATE'] = dfPC['POSTDATE'].str.replace(r",", '')
dfPC['POSTDATE'] = dfPC['POSTDATE'].str.replace(r",", '')
dfPC['COMMENTDATETIME'] = dfPC['COMMENTDATETIME'].str.replace(r", License: CC BY-SA 4.0", '')
dfPC['COMMENTUSERNAME'] = dfPC['COMMENTUSERNAME'].str.replace(r"segFault", " ")
display(dfPC.head(1))

dfAAC['ANSWERVOTECOUNTS'] = dfAAC['ANSWERVOTECOUNTS'].str.replace(r"(", '')
dfAAC['ANSWERVOTECOUNTS'] = dfAAC['ANSWERVOTECOUNTS'].str.replace(r")", '')
dfAAC['ANSWERVOTECOUNTS'] = dfAAC['ANSWERVOTECOUNTS'].str.replace(r"'", '')
dfAAC['ANSWERVOTECOUNTS'] = dfAAC['ANSWERVOTECOUNTS'].str.replace(r",", '')

dfAAC['ANSWERDATETIME'] = dfAAC['ANSWERDATETIME'].str.replace(r", License: CC BY-SA 4.0", '')
display(dfAAC.head(1))

dFACT['ANSWERCMTVOTECOUNTS'] = dFACT['ANSWERCMTVOTECOUNTS'].str.replace(r"(", '')
dFACT['ANSWERCMTVOTECOUNTS'] = dFACT['ANSWERCMTVOTECOUNTS'].str.replace(r")", '')
dFACT['ANSWERCMTVOTECOUNTS'] = dFACT['ANSWERCMTVOTECOUNTS'].str.replace(r"'", '')
dFACT['ANSWERCMTVOTECOUNTS'] = dFACT['ANSWERCMTVOTECOUNTS'].str.replace(r",", '')

dFACT['ANSWERCMTID'] = dFACT['ANSWERCMTID'].str.replace(r"(", '')
dFACT['ANSWERCMTID'] = dFACT['ANSWERCMTID'].str.replace(r")", '')
dFACT['ANSWERCMTID'] = dFACT['ANSWERCMTID'].str.replace(r"'", '')
dFACT['ANSWERCMTID'] = dFACT['ANSWERCMTID'].str.replace(r",", '')
display(dFACT.head(1))
# Out:
#      POSTID                                           POSTLINK  \
# 0  76144358  https://stackoverflow.com/questions/76144358/i...
#
#                                            POSTTITLE  \
# 0  I'm creating a color blender using Adobe Anima...
#
#                                             POSTBODY              POSTDATE  \
# 0  \n                \n<p>I'm using Adobe Animate...  2023-05-01 01:47:04Z
#
#   POSTVOTECOUNTS  TYPE
# 0             -1  post
#       POSTID                                           POSTLINK  \
# 36  76143948  https://stackoverflow.com/questions/76143948/r...
#
#                           POSTTITLE  \
# 36  Resize with JavaScript (JQuery)
#
#                                              POSTBODY              POSTDATE  \
# 36  \n                \n<p>I want to resize multip...  2023-04-30 23:07:53Z
#
#    POSTVOTECOUNTS          COMMENTID  COMMENTSCORE COMMENTUSERNAME  \
# 36              1  comment-134283400           NaN        disinfor
#
#                                           COMMENTTEXT       COMMENTDATETIME  \
# 36  I updated my answer a bit to give another exam...  2023-05-01 01:21:53Z
#
#             TYPE
# 36  post_comment
#      POSTID                                     POSTTITLE    ANSWERID  \
# 2  36280818  How to convert file to base64 in JavaScript?  36281449.0
#
#                                           ANSWERTEXT  \
# 2  Try the solution using the FileReader class:\n...
#
#                                           ANSWERBODY  \
# 2  ('\n<p>Try the solution using the <code>FileRe...
#
#                                 ANSWERDATETIME ANSWERVOTECOUNTS    TYPE
# 2  2017-06-09 19:16:52Z, License: CC BY-SA 3.0              429  answer
#      POSTID                                     POSTTITLE    ANSWERID  \
# 3  36280818  How to convert file to base64 in JavaScript?  36281449.0
#
#   ANSWERCMTID                                      ANSWERCMTTEXT  \
# 3    75927236  read more about FileReader API: developer.mozi...
#
#                                        ANSWERCMTBODY     ANSWERCMTDATETIME  \
# 3  ('\n                \n                <span cl...  Jun 9, 2017 at 19:16
#
#   ANSWERCMTVOTECOUNTS            TYPE
# 3                   3  answer_comment

# %%
# transform empty values to NaN
dPOST = dPOST.replace(r'^\s*$', np.nan, regex=True)
dfPC = dfPC.replace(r'^\s*$', np.nan, regex=True)
dfAAC = dfAAC.replace(r'^\s*$', np.nan, regex=True)
dFACT = dFACT.replace(r'^\s*$', np.nan, regex=True)

display(dPOST.head(1))
display(dfPC.head(1))
display(dfAAC.head(1))
display(dFACT.head(1))
# Out:
#      POSTID                                           POSTLINK  \
# 0  76144358  https://stackoverflow.com/questions/76144358/i...
#
#                                            POSTTITLE  \
# 0  I'm creating a color blender using Adobe Anima...
#
#                                             POSTBODY              POSTDATE  \
# 0  \n                \n<p>I'm using Adobe Animate...  2023-05-01 01:47:04Z
#
#   POSTVOTECOUNTS  TYPE
# 0             -1  post
#       POSTID                                           POSTLINK  \
# 36  76143948  https://stackoverflow.com/questions/76143948/r...
#
#                           POSTTITLE  \
# 36  Resize with JavaScript (JQuery)
#
#                                              POSTBODY              POSTDATE  \
# 36  \n                \n<p>I want to resize multip...  2023-04-30 23:07:53Z
#
#    POSTVOTECOUNTS          COMMENTID  COMMENTSCORE COMMENTUSERNAME  \
# 36              1  comment-134283400           NaN        disinfor
#
#                                           COMMENTTEXT       COMMENTDATETIME  \
# 36  I updated my answer a bit to give another exam...  2023-05-01 01:21:53Z
#
#             TYPE
# 36  post_comment
#      POSTID                                     POSTTITLE    ANSWERID  \
# 2  36280818  How to convert file to base64 in JavaScript?  36281449.0
#
#                                           ANSWERTEXT  \
# 2  Try the solution using the FileReader class:\n...
#
#                                           ANSWERBODY  \
# 2  ('\n<p>Try the solution using the <code>FileRe...
#
#                                 ANSWERDATETIME ANSWERVOTECOUNTS    TYPE
# 2  2017-06-09 19:16:52Z, License: CC BY-SA 3.0              429  answer
#      POSTID                                     POSTTITLE    ANSWERID  \
# 3  36280818  How to convert file to base64 in JavaScript?  36281449.0
#
#   ANSWERCMTID                                      ANSWERCMTTEXT  \
# 3    75927236  read more about FileReader API: developer.mozi...
#
#                                        ANSWERCMTBODY     ANSWERCMTDATETIME  \
# 3  ('\n                \n                <span cl...  Jun 9, 2017 at 19:16
#
#   ANSWERCMTVOTECOUNTS            TYPE
# 3                   3  answer_comment

# %%
dfPC = dfPC.fillna(0)
dFACT = dFACT.fillna(0)

# %%
display(dPOST.head(1))
display(dfPC.head(1))
display(dfAAC.head(1))
display(dFACT.head(1))
# Out:
#      POSTID                                           POSTLINK  \
# 0  76144358  https://stackoverflow.com/questions/76144358/i...
#
#                                            POSTTITLE  \
# 0  I'm creating a color blender using Adobe Anima...
#
#                                             POSTBODY              POSTDATE  \
# 0  \n                \n<p>I'm using Adobe Animate...  2023-05-01 01:47:04Z
#
#   POSTVOTECOUNTS  TYPE
# 0             -1  post
#       POSTID                                           POSTLINK  \
# 36  76143948  https://stackoverflow.com/questions/76143948/r...
#
#                           POSTTITLE  \
# 36  Resize with JavaScript (JQuery)
#
#                                              POSTBODY              POSTDATE  \
# 36  \n                \n<p>I want to resize multip...  2023-04-30 23:07:53Z
#
#    POSTVOTECOUNTS          COMMENTID  COMMENTSCORE COMMENTUSERNAME  \
# 36              1  comment-134283400           0.0        disinfor
#
#                                           COMMENTTEXT       COMMENTDATETIME  \
# 36  I updated my answer a bit to give another exam...  2023-05-01 01:21:53Z
#
#             TYPE
# 36  post_comment
#      POSTID                                     POSTTITLE    ANSWERID  \
# 2  36280818  How to convert file to base64 in JavaScript?  36281449.0
#
#                                           ANSWERTEXT  \
# 2  Try the solution using the FileReader class:\n...
#
#                                           ANSWERBODY  \
# 2  ('\n<p>Try the solution using the <code>FileRe...
#
#                                 ANSWERDATETIME ANSWERVOTECOUNTS    TYPE
# 2  2017-06-09 19:16:52Z, License: CC BY-SA 3.0              429  answer
#      POSTID                                     POSTTITLE    ANSWERID  \
# 3  36280818  How to convert file to base64 in JavaScript?  36281449.0
#
#   ANSWERCMTID                                      ANSWERCMTTEXT  \
# 3    75927236  read more about FileReader API: developer.mozi...
#
#                                        ANSWERCMTBODY     ANSWERCMTDATETIME  \
# 3  ('\n                \n                <span cl...  Jun 9, 2017 at 19:16
#
#   ANSWERCMTVOTECOUNTS            TYPE
# 3                   3  answer_comment

# %%
dPOST.to_csv('javascript-post.csv')
dfPC.to_csv('javascript-post-comment.csv')
dfAAC.to_csv('javascript-post-answer.csv')
dFACT.to_csv('javascript-post-answer-comment.csv')

# %%
# reset warnings
warnings.resetwarnings()
