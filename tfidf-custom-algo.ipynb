# %%
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem.snowball import SnowballStemmer
import nltk
import re
import string
import numpy as np
import spacy
import pandas as pd
from fuzzywuzzy import fuzz
from nltk.corpus import stopwords
import heapq
import yaml
from nltk.stem import WordNetLemmatizer, PorterStemmer

from transformers import AutoTokenizer, AutoModelForSequenceClassification, AutoConfig
from scipy.special import softmax
import numpy as np
from array import array
import copy

nlp = spacy.load('en_core_web_lg')

df = pd.read_csv('./scraper/archive/javascript.csv', names=["POSTID", "POSTLINK", "POSTTITLE", "POSTBODY", "POSTDATE", "POSTVOTECOUNTS", "COMMENTID", "COMMENTSCORE", "COMMENTUSERNAME", "COMMENTTEXT", "COMMENTDATETIME", "ANSWERID", "ANSWERTEXT", "ANSWERBODY", "ANSWERDATETIME", "ANSWERVOTECOUNTS", "ANSWERCMTID", "ANSWERCMTTEXT", "ANSWERCMTBODY", "ANSWERCMTDATETIME", "ANSWERCMTVOTECOUNTS" , "TYPE"])

print(df.shape)
display(df.head())

print("\n")
print("All Columns DF")
df.columns
# Out:
# (101724, 22)
#      POSTID                                           POSTLINK  \
# 0  76144358  https://stackoverflow.com/questions/76144358/i...
# 1  36280818  https://stackoverflow.com/questions/36280818/h...
# 2  36280818  https://stackoverflow.com/questions/36280818/h...
# 3  36280818  https://stackoverflow.com/questions/36280818/h...
# 4  36280818  https://stackoverflow.com/questions/36280818/h...
#
#                                            POSTTITLE  \
# 0  I'm creating a color blender using Adobe Anima...
# 1       How to convert file to base64 in JavaScript?
# 2       How to convert file to base64 in JavaScript?
# 3       How to convert file to base64 in JavaScript?
# 4       How to convert file to base64 in JavaScript?
#
#                                             POSTBODY  \
# 0  \n                \n<p>I'm using Adobe Animate...
# 1  \n                \n<p><strong>UPD</strong> Ty...
# 2  \n                \n<p><strong>UPD</strong> Ty...
# 3  \n                \n<p><strong>UPD</strong> Ty...
# 4  \n                \n<p><strong>UPD</strong> Ty...
#
#                     POSTDATE POSTVOTECOUNTS COMMENTID  COMMENTSCORE  \
# 0  ('2023-05-01 01:47:04Z',)        ('-1',)       NaN           NaN
# 1  ('2016-03-29 09:49:26Z',)       ('355',)       NaN           NaN
# 2  ('2016-03-29 09:49:26Z',)       ('355',)       NaN           NaN
# 3  ('2016-03-29 09:49:26Z',)       ('355',)       NaN           NaN
# 4  ('2016-03-29 09:49:26Z',)       ('355',)       NaN           NaN
#
#   COMMENTUSERNAME COMMENTTEXT  ...  \
# 0             NaN         NaN  ...
# 1             NaN         NaN  ...
# 2             NaN         NaN  ...
# 3             NaN         NaN  ...
# 4             NaN         NaN  ...
#
#                                           ANSWERTEXT  \
# 0                                                NaN
# 1                                                NaN
# 2  Try the solution using the FileReader class:\n...
# 3  Try the solution using the FileReader class:\n...
# 4  Try the solution using the FileReader class:\n...
#
#                                           ANSWERBODY  \
# 0                                                NaN
# 1                                                NaN
# 2  ('\n<p>Try the solution using the <code>FileRe...
# 3  ('\n<p>Try the solution using the <code>FileRe...
# 4  ('\n<p>Try the solution using the <code>FileRe...
#
#                                 ANSWERDATETIME ANSWERVOTECOUNTS  \
# 0                                          NaN              NaN
# 1                                          NaN              NaN
# 2  2017-06-09 19:16:52Z, License: CC BY-SA 3.0         ('429',)
# 3  2017-06-09 19:16:52Z, License: CC BY-SA 3.0         ('429',)
# 4  2017-06-09 19:16:52Z, License: CC BY-SA 3.0         ('429',)
#
#      ANSWERCMTID                                      ANSWERCMTTEXT  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3  ('75927236',)  read more about FileReader API: developer.mozi...
# 4  ('81338095',)  I tried to use return reader.result from the g...
#
#                                        ANSWERCMTBODY     ANSWERCMTDATETIME  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3  ('\n                \n                <span cl...  Jun 9, 2017 at 19:16
# 4  ('\n                \n                <span cl...   Nov 9, 2017 at 5:35
#
#   ANSWERCMTVOTECOUNTS            TYPE
# 0                 NaN            post
# 1                 NaN            post
# 2                 NaN          answer
# 3              ('3',)  answer_comment
# 4             ('20',)  answer_comment
#
# [5 rows x 22 columns]
# All Columns DF
# Index(['POSTID', 'POSTLINK', 'POSTTITLE', 'POSTBODY', 'POSTDATE',
#        'POSTVOTECOUNTS', 'COMMENTID', 'COMMENTSCORE', 'COMMENTUSERNAME',
#        'COMMENTTEXT', 'COMMENTDATETIME', 'ANSWERID', 'ANSWERTEXT',
#        'ANSWERBODY', 'ANSWERDATETIME', 'ANSWERVOTECOUNTS', 'ANSWERCMTID',
#        'ANSWERCMTTEXT', 'ANSWERCMTBODY', 'ANSWERCMTDATETIME',
#        'ANSWERCMTVOTECOUNTS', 'TYPE'],
#       dtype='object')

# %%
unique_values = df['POSTTITLE'].unique()
print("There are a total of {} unique titles".format(len(unique_values)))

query = 'What is the correct way to check for string equality in JavaScript? ' 
''' case sensitive '''
''' convert date to string '''
''' Event loop '''
''' What is the correct way to check for string equality in JavaScript? '''
''' How to compare two strings value '''
# Out:
# There are a total of 16262 unique titles
# ' How to compare two strings value '

# %% [markdown]
# ## String Similarity

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("roberta-large-mnli")
model = AutoModelForSequenceClassification.from_pretrained("roberta-large-mnli")

def test_entailment(text1, text2):
    batch = tokenizer(text1, text2, return_tensors='pt').to(model.device)
    with torch.no_grad():
        proba = torch.softmax(model(**batch).logits, -1)
    return proba.cpu().numpy()[0, model.config.label2id['ENTAILMENT']]

def test_equivalence(text1, text2):
    return test_entailment(text1, text2) * test_entailment(text2, text1) * 100
# Out:
# Some weights of the model checkpoint at roberta-large-mnli were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def calPartialRatio (str1, str2):
    return fuzz.partial_ratio(str1, str2)

def calTokenSortRatio (str1, str2):
    return fuzz.token_sort_ratio(str1, str2)
  
def calTokenSetRatio (str1, str2):
    return fuzz.token_set_ratio(str1, str2)

fuzzywuzzy_df = pd.DataFrame(columns=['postId', 'title', 'partial_ratio', 'token_sort_ratio', 'token_set_ratio', 'bert_similarity'])
for unique_value in unique_values:
    # find the postId of the unique value
    postId = df[df['POSTTITLE'] == unique_value]['POSTID'].tolist()[0]
    fuzzywuzzy_df = pd.concat([fuzzywuzzy_df, pd.DataFrame({'postId': postId , 'title': unique_value, 'partial_ratio': calPartialRatio(unique_value, query), 'token_sort_ratio': calTokenSortRatio(unique_value, query), 'token_set_ratio': calTokenSetRatio(unique_value, query)}, index=[0])] )

matchesPR = fuzzywuzzy_df.sort_values(by=['partial_ratio'], ascending=False)
matchesPR = matchesPR[matchesPR['partial_ratio'] > 50]

matchesTS = fuzzywuzzy_df.sort_values(by=['token_sort_ratio'], ascending=False)
matchesTS = matchesTS[matchesTS['token_sort_ratio'] > 50]

matchesTSE = fuzzywuzzy_df.sort_values(by=['token_set_ratio'], ascending=False)
matchesTSE = matchesTSE[matchesTSE['token_set_ratio'] > 80]

Top10MathesMerged = pd.concat([matchesTS, matchesPR]).drop_duplicates()
Top10MathesMerged['average'] = (Top10MathesMerged['token_sort_ratio'] + Top10MathesMerged['partial_ratio']) / 2
Top10MathesMerged = Top10MathesMerged.sort_values(by=['average'], ascending=False)

Top10MathesMerged = Top10MathesMerged[Top10MathesMerged['average'] > 50]
display(matchesTSE)
print("{} number of titles found".format(len(matchesTSE)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb Cell 5 in <cell line: 11>()
#      <a href='vscode-notebook-cell:/Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> for unique_value in unique_values:
#      <a href='vscode-notebook-cell:/Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a>     # find the postId of the unique value
#      <a href='vscode-notebook-cell:/Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a>     postId = df[df['POSTTITLE'] == unique_value]['POSTID'].tolist()[0]
# ---> <a href='vscode-notebook-cell:/Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a>     fuzzywuzzy_df = pd.concat([fuzzywuzzy_df, pd.DataFrame({'postId': postId , 'title': unique_value, 'partial_ratio': calPartialRatio(unique_value, query), 'token_sort_ratio': calTokenSortRatio(unique_value, query), 'token_set_ratio': calTokenSetRatio(unique_value, query), "bert_similarity": test_equivalence(unique_value, query)}, index=[0])] )
#      <a href='vscode-notebook-cell:/Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a> matchesPR = fuzzywuzzy_df.sort_values(by=['partial_ratio'], ascending=False)
#      <a href='vscode-notebook-cell:/Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb#W5sZmlsZQ%3D%3D?line=16'>17</a> matchesPR = matchesPR[matchesPR['partial_ratio'] > 50]
#
# /Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb Cell 5 in test_equivalence(text1, text2)
#      <a href='vscode-notebook-cell:/Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a> def test_equivalence(text1, text2):
# ---> <a href='vscode-notebook-cell:/Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a>     return test_entailment(text1, text2) * test_entailment(text2, text1) * 100
#
# /Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb Cell 5 in test_entailment(text1, text2)
#       <a href='vscode-notebook-cell:/Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> batch = tokenizer(text1, text2, return_tensors='pt').to(model.device)
#       <a href='vscode-notebook-cell:/Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> with torch.no_grad():
# ---> <a href='vscode-notebook-cell:/Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a>     proba = torch.softmax(model(**batch).logits, -1)
#      <a href='vscode-notebook-cell:/Users/shaun/Time-Series-Based-Text-Summarization/tfidf-custom-algo.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> return proba.cpu().numpy()[0, model.config.label2id['ENTAILMENT']]
#
# File ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py:1215, in RobertaForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1207 r"""
#    1208 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1209     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1210     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1211     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1212 """
#    1213 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1215 outputs = self.roberta(
#    1216     input_ids,
#    1217     attention_mask=attention_mask,
#    1218     token_type_ids=token_type_ids,
#    1219     position_ids=position_ids,
#    1220     head_mask=head_mask,
#    1221     inputs_embeds=inputs_embeds,
#    1222     output_attentions=output_attentions,
#    1223     output_hidden_states=output_hidden_states,
#    1224     return_dict=return_dict,
#    1225 )
#    1226 sequence_output = outputs[0]
#    1227 logits = self.classifier(sequence_output)
#
# File ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py:853, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     844 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     846 embedding_output = self.embeddings(
#     847     input_ids=input_ids,
#     848     position_ids=position_ids,
#    (...)
#     851     past_key_values_length=past_key_values_length,
#     852 )
# --> 853 encoder_outputs = self.encoder(
#     854     embedding_output,
#     855     attention_mask=extended_attention_mask,
#     856     head_mask=head_mask,
#     857     encoder_hidden_states=encoder_hidden_states,
#     858     encoder_attention_mask=encoder_extended_attention_mask,
#     859     past_key_values=past_key_values,
#     860     use_cache=use_cache,
#     861     output_attentions=output_attentions,
#     862     output_hidden_states=output_hidden_states,
#     863     return_dict=return_dict,
#     864 )
#     865 sequence_output = encoder_outputs[0]
#     866 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py:527, in RobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     518     layer_outputs = torch.utils.checkpoint.checkpoint(
#     519         create_custom_forward(layer_module),
#     520         hidden_states,
#    (...)
#     524         encoder_attention_mask,
#     525     )
#     526 else:
# --> 527     layer_outputs = layer_module(
#     528         hidden_states,
#     529         attention_mask,
#     530         layer_head_mask,
#     531         encoder_hidden_states,
#     532         encoder_attention_mask,
#     533         past_key_value,
#     534         output_attentions,
#     535     )
#     537 hidden_states = layer_outputs[0]
#     538 if use_cache:
#
# File ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py:454, in RobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     451     cross_attn_present_key_value = cross_attention_outputs[-1]
#     452     present_key_value = present_key_value + cross_attn_present_key_value
# --> 454 layer_output = apply_chunking_to_forward(
#     455     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     456 )
#     457 outputs = (layer_output,) + outputs
#     459 # if decoder, return the attn key/values as the last output
#
# File ~/miniforge3/lib/python3.9/site-packages/transformers/pytorch_utils.py:246, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     243     # concatenate output at same dimension
#     244     return torch.cat(output_chunks, dim=chunk_dim)
# --> 246 return forward_fn(*input_tensors)
#
# File ~/miniforge3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py:466, in RobertaLayer.feed_forward_chunk(self, attention_output)
#     465 def feed_forward_chunk(self, attention_output):
# --> 466     intermediate_output = self.intermediate(attention_output)
#     467     layer_output = self.output(intermediate_output, attention_output)
#     468     return layer_output
#
# File ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py:364, in RobertaIntermediate.forward(self, hidden_states)
#     363 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 364     hidden_states = self.dense(hidden_states)
#     365     hidden_states = self.intermediate_act_fn(hidden_states)
#     366     return hidden_states
#
# File ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/lib/python3.9/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
df = df[df['POSTID'].isin(matchesTSE['postId'])]

# populate df with token set ratio value
merged_df = pd.merge(df, matchesTSE, left_on='POSTID', right_on='postId', how='left')

merged_df.to_csv('convertdatetostr-tsematches.csv')

# %% [markdown]
# # Input of tsematches

# %%
df = pd.read_csv('convertdatetostr-tsematches.csv')

# %%
df['POSTDATE'] = df['POSTDATE'].str.replace(r"(", '')
df['POSTDATE'] = df['POSTDATE'].str.replace(r")", '')
df['POSTDATE'] = df['POSTDATE'].str.replace(r"'", '')
df['POSTDATE'] = df['POSTDATE'].str.replace(r",", '')

df['POSTVOTECOUNTS'] = df['POSTVOTECOUNTS'].str.replace(r"(", '')
df['POSTVOTECOUNTS'] = df['POSTVOTECOUNTS'].str.replace(r")", '')
df['POSTVOTECOUNTS'] = df['POSTVOTECOUNTS'].str.replace(r"'", '')
df['POSTVOTECOUNTS'] = df['POSTVOTECOUNTS'].str.replace(r",", '')
df["POSTVOTECOUNTS"] = df["POSTVOTECOUNTS"].astype(int)
# Out:
# /var/folders/x0/f6tjyw_s7vqbx5gcpvt0z31w0000gn/T/ipykernel_23792/1094532588.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['POSTDATE'] = df['POSTDATE'].str.replace(r"(", '')
# /var/folders/x0/f6tjyw_s7vqbx5gcpvt0z31w0000gn/T/ipykernel_23792/1094532588.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['POSTDATE'] = df['POSTDATE'].str.replace(r")", '')
# /var/folders/x0/f6tjyw_s7vqbx5gcpvt0z31w0000gn/T/ipykernel_23792/1094532588.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['POSTVOTECOUNTS'] = df['POSTVOTECOUNTS'].str.replace(r"(", '')
# /var/folders/x0/f6tjyw_s7vqbx5gcpvt0z31w0000gn/T/ipykernel_23792/1094532588.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['POSTVOTECOUNTS'] = df['POSTVOTECOUNTS'].str.replace(r")", '')

# %%
from datetime import datetime
date_format = "%Y-%m-%d %H:%M:%SZ"

df["POSTDATE"] = df["POSTDATE"].apply(lambda x: datetime.strptime(x, date_format))

# %%
def calculate_time_score(df, date_column):
    current_time = datetime.now()
    df[date_column] = pd.to_datetime(df[date_column])  # Convert the date column to datetime
    
    # Calculate the range of time differences
    time_diffs = (current_time - df[date_column]).dt.total_seconds() / 60
    min_time_diff = np.min(time_diffs)
    max_time_diff = np.max(time_diffs)
    
    # Calculate the time score for each row
    time_scores = 100 - ((time_diffs - min_time_diff) / (max_time_diff - min_time_diff)) * 100
    time_scores = np.maximum(np.minimum(time_scores, 100), 1)  # Ensure scores are within the range of 1 to 100
    
    return time_scores

time_scores = calculate_time_score(df, "POSTDATE")

df["time_score"] = time_scores

# %%
def calculate_vote_count_score(df, vote_column):
    min_vote_count = df[vote_column].min()
    max_vote_count = df[vote_column].max()

    print("{} min vote count, {} max vote count".format(min_vote_count, max_vote_count))

    vote_counts = df[vote_column]
    vote_count_scores = 100 - ((vote_counts - min_vote_count) / (max_vote_count - min_vote_count)) * 100
    vote_count_scores = np.maximum(np.minimum(vote_count_scores, 100), 1)  # Ensure scores are within the range of 1 to 100

    return vote_count_scores
  
  
votecount_scores = calculate_vote_count_score(df, "POSTVOTECOUNTS")
df['vote_score'] = votecount_scores
# Out:
# 0 min vote count, 2639 max vote count

# %%
sorted = df.sort_values(by=['vote_score'], ascending=False)
sorted
# Out:
#      Unnamed: 0    POSTID                                           POSTLINK  \
# 171         171  75571616  https://stackoverflow.com/questions/75571616/q...
# 242         242  74497558  https://stackoverflow.com/questions/74497558/a...
# 233         233   3001866  https://stackoverflow.com/questions/3001866/ca...
# 234         234   3001866  https://stackoverflow.com/questions/3001866/ca...
# 235         235   3001866  https://stackoverflow.com/questions/3001866/ca...
# ..          ...       ...                                                ...
# 139         139   4059147  https://stackoverflow.com/questions/4059147/ch...
# 140         140   4059147  https://stackoverflow.com/questions/4059147/ch...
# 141         141   4059147  https://stackoverflow.com/questions/4059147/ch...
# 142         142   4059147  https://stackoverflow.com/questions/4059147/ch...
# 125         125   4059147  https://stackoverflow.com/questions/4059147/ch...
#
#                                          POSTTITLE  \
# 171                             Quiz in Javascript
# 242                            Alert in Javascript
# 233                      Call the id in JavaScript
# 234                      Call the id in JavaScript
# 235                      Call the id in JavaScript
# ..                                             ...
# 139  Check if a variable is a string in JavaScript
# 140  Check if a variable is a string in JavaScript
# 141  Check if a variable is a string in JavaScript
# 142  Check if a variable is a string in JavaScript
# 125  Check if a variable is a string in JavaScript
#
#                                               POSTBODY            POSTDATE  \
# 171  \n                \n<p>I'm quite new to progra... 2023-02-26 11:18:47
# 242  \n                \n<p>On my order site, I hav... 2022-11-19 04:29:33
# 233  \n                \n<p>I have a span like this... 2010-06-08 22:43:21
# 234  \n                \n<p>I have a span like this... 2010-06-08 22:43:21
# 235  \n                \n<p>I have a span like this... 2010-06-08 22:43:21
# ..                                                 ...                 ...
# 139  \n                \n<p>How can I determine whe... 2010-10-30 14:36:34
# 140  \n                \n<p>How can I determine whe... 2010-10-30 14:36:34
# 141  \n                \n<p>How can I determine whe... 2010-10-30 14:36:34
# 142  \n                \n<p>How can I determine whe... 2010-10-30 14:36:34
# 125  \n                \n<p>How can I determine whe... 2010-10-30 14:36:34
#
#      POSTVOTECOUNTS          COMMENTID  COMMENTSCORE  COMMENTUSERNAME  ...  \
# 171               0                NaN           NaN              NaN  ...
# 242               0  comment-131507612           NaN  Sebastian Simon  ...
# 233               0                NaN           NaN              NaN  ...
# 234               0    comment-3066613           NaN       Asim Zaidi  ...
# 235               0    comment-3066636           NaN    Marcel Korpel  ...
# ..              ...                ...           ...              ...  ...
# 139            2639                NaN           NaN              NaN  ...
# 140            2639                NaN           NaN              NaN  ...
# 141            2639                NaN           NaN              NaN  ...
# 142            2639                NaN           NaN              NaN  ...
# 125            2639                NaN           NaN              NaN  ...
#
#          ANSWERCMTDATETIME ANSWERCMTVOTECOUNTS            TYPE    postId  \
# 171                    NaN                 NaN            post  75571616
# 242                    NaN                 NaN    post_comment  74497558
# 233                    NaN                 NaN            post   3001866
# 234                    NaN                 NaN    post_comment   3001866
# 235                    NaN                 NaN    post_comment   3001866
# ..                     ...                 ...             ...       ...
# 139   May 7, 2018 at 19:36              ('4',)  answer_comment   4059147
# 140   May 8, 2018 at 22:03              ('4',)  answer_comment   4059147
# 141  Feb 24, 2020 at 10:48              ('1',)  answer_comment   4059147
# 142  Apr 24, 2020 at 16:59              ('1',)  answer_comment   4059147
# 125  Jul 10, 2021 at 22:33              ('3',)  answer_comment   4059147
#
#                                              title partial_ratio  \
# 171                             Quiz in Javascript            78
# 242                            Alert in Javascript            79
# 233                      Call the id in JavaScript            68
# 234                      Call the id in JavaScript            68
# 235                      Call the id in JavaScript            68
# ..                                             ...           ...
# 139  Check if a variable is a string in JavaScript            65
# 140  Check if a variable is a string in JavaScript            65
# 141  Check if a variable is a string in JavaScript            65
# 142  Check if a variable is a string in JavaScript            65
# 125  Check if a variable is a string in JavaScript            65
#
#     token_sort_ratio token_set_ratio  time_score vote_score
# 171               36              84  100.000000      100.0
# 242               40              81   97.960294      100.0
# 233               48              81    4.561801      100.0
# 234               48              81    4.561801      100.0
# 235               48              81    4.561801      100.0
# ..               ...             ...         ...        ...
# 139               63              81    7.513209        1.0
# 140               63              81    7.513209        1.0
# 141               63              81    7.513209        1.0
# 142               63              81    7.513209        1.0
# 125               63              81    7.513209        1.0
#
# [250 rows x 30 columns]

# %%
fuzzy_weightage = 0.8
time_weightage = 0.2

# %%
results = []
for index, row in df.iterrows():
    similarity_score = row['token_set_ratio']
    time_score = row['time_score']
    
    weighted_score = (fuzzy_weightage * similarity_score) + (time_weightage * time_score)
    
    results.append({"POSTID": row["POSTID"], "weighted_score": weighted_score})

results.sort(key=lambda x: x["weighted_score"], reverse=True)

results_df = pd.DataFrame(results)

# Print the sorted results DataFrame
print(results_df)
# Out:
#        POSTID  weighted_score
# 0    75571616       87.200000
# 1    74497558       84.392059
# 2    74497558       84.392059
# 3    74497558       84.392059
# 4    26100218       73.777932
# ..        ...             ...
# 245   1646698       65.000000
# 246   1646698       65.000000
# 247   1646698       65.000000
# 248   1646698       65.000000
# 249   1646698       65.000000
#
# [250 rows x 2 columns]

# %%
df[df['POSTID'] == results_df['POSTID'][5]]
# Out:
#    Unnamed: 0    POSTID                                           POSTLINK  \
# 0           0  26100218  https://stackoverflow.com/questions/26100218/r...
# 1           1  26100218  https://stackoverflow.com/questions/26100218/r...
# 2           2  26100218  https://stackoverflow.com/questions/26100218/r...
# 3           3  26100218  https://stackoverflow.com/questions/26100218/r...
# 4           4  26100218  https://stackoverflow.com/questions/26100218/r...
# 5           5  26100218  https://stackoverflow.com/questions/26100218/r...
#
#                       POSTTITLE  \
# 0  Reverse String in JavaScript
# 1  Reverse String in JavaScript
# 2  Reverse String in JavaScript
# 3  Reverse String in JavaScript
# 4  Reverse String in JavaScript
# 5  Reverse String in JavaScript
#
#                                             POSTBODY            POSTDATE  \
# 0  \n                \n<p>I wrote a JS constructo... 2014-09-29 12:41:59
# 1  \n                \n<p>I wrote a JS constructo... 2014-09-29 12:41:59
# 2  \n                \n<p>I wrote a JS constructo... 2014-09-29 12:41:59
# 3  \n                \n<p>I wrote a JS constructo... 2014-09-29 12:41:59
# 4  \n                \n<p>I wrote a JS constructo... 2014-09-29 12:41:59
# 5  \n                \n<p>I wrote a JS constructo... 2014-09-29 12:41:59
#
#    POSTVOTECOUNTS         COMMENTID  COMMENTSCORE  COMMENTUSERNAME  ...  \
# 0               2               NaN           NaN              NaN  ...
# 1               2  comment-40900823           4.0  Frédéric Hamidi  ...
# 2               2  comment-40900875           4.0  Frédéric Hamidi  ...
# 3               2  comment-40900914           NaN       user663031  ...
# 4               2  comment-40900984           NaN       user663031  ...
# 5               2  comment-40901194           NaN       user663031  ...
#
#   ANSWERCMTDATETIME ANSWERCMTVOTECOUNTS          TYPE    postId  \
# 0               NaN                 NaN          post  26100218
# 1               NaN                 NaN  post_comment  26100218
# 2               NaN                 NaN  post_comment  26100218
# 3               NaN                 NaN  post_comment  26100218
# 4               NaN                 NaN  post_comment  26100218
# 5               NaN                 NaN  post_comment  26100218
#
#                           title partial_ratio token_sort_ratio  \
# 0  Reverse String in JavaScript            68               43
# 1  Reverse String in JavaScript            68               43
# 2  Reverse String in JavaScript            68               43
# 3  Reverse String in JavaScript            68               43
# 4  Reverse String in JavaScript            68               43
# 5  Reverse String in JavaScript            68               43
#
#   token_set_ratio time_score vote_score
# 0              83  36.889661  99.924214
# 1              83  36.889661  99.924214
# 2              83  36.889661  99.924214
# 3              83  36.889661  99.924214
# 4              83  36.889661  99.924214
# 5              83  36.889661  99.924214
#
# [6 rows x 30 columns]

# %%
df[df['POSTID'] == results_df['POSTID'][len(results_df) - 1]]
# Out:
#      Unnamed: 0   POSTID                                           POSTLINK  \
# 172         172  1646698  https://stackoverflow.com/questions/1646698/wh...
# 173         173  1646698  https://stackoverflow.com/questions/1646698/wh...
# 174         174  1646698  https://stackoverflow.com/questions/1646698/wh...
# 175         175  1646698  https://stackoverflow.com/questions/1646698/wh...
# 176         176  1646698  https://stackoverflow.com/questions/1646698/wh...
# 177         177  1646698  https://stackoverflow.com/questions/1646698/wh...
# 178         178  1646698  https://stackoverflow.com/questions/1646698/wh...
# 179         179  1646698  https://stackoverflow.com/questions/1646698/wh...
# 180         180  1646698  https://stackoverflow.com/questions/1646698/wh...
# 181         181  1646698  https://stackoverflow.com/questions/1646698/wh...
# 182         182  1646698  https://stackoverflow.com/questions/1646698/wh...
# 183         183  1646698  https://stackoverflow.com/questions/1646698/wh...
# 184         184  1646698  https://stackoverflow.com/questions/1646698/wh...
# 185         185  1646698  https://stackoverflow.com/questions/1646698/wh...
# 186         186  1646698  https://stackoverflow.com/questions/1646698/wh...
# 187         187  1646698  https://stackoverflow.com/questions/1646698/wh...
# 188         188  1646698  https://stackoverflow.com/questions/1646698/wh...
# 189         189  1646698  https://stackoverflow.com/questions/1646698/wh...
# 190         190  1646698  https://stackoverflow.com/questions/1646698/wh...
# 191         191  1646698  https://stackoverflow.com/questions/1646698/wh...
# 192         192  1646698  https://stackoverflow.com/questions/1646698/wh...
# 193         193  1646698  https://stackoverflow.com/questions/1646698/wh...
# 194         194  1646698  https://stackoverflow.com/questions/1646698/wh...
# 195         195  1646698  https://stackoverflow.com/questions/1646698/wh...
# 196         196  1646698  https://stackoverflow.com/questions/1646698/wh...
# 197         197  1646698  https://stackoverflow.com/questions/1646698/wh...
# 198         198  1646698  https://stackoverflow.com/questions/1646698/wh...
# 199         199  1646698  https://stackoverflow.com/questions/1646698/wh...
# 200         200  1646698  https://stackoverflow.com/questions/1646698/wh...
# 201         201  1646698  https://stackoverflow.com/questions/1646698/wh...
#
#                                     POSTTITLE  \
# 172  What is the 'new' keyword in JavaScript?
# 173  What is the 'new' keyword in JavaScript?
# 174  What is the 'new' keyword in JavaScript?
# 175  What is the 'new' keyword in JavaScript?
# 176  What is the 'new' keyword in JavaScript?
# 177  What is the 'new' keyword in JavaScript?
# 178  What is the 'new' keyword in JavaScript?
# 179  What is the 'new' keyword in JavaScript?
# 180  What is the 'new' keyword in JavaScript?
# 181  What is the 'new' keyword in JavaScript?
# 182  What is the 'new' keyword in JavaScript?
# 183  What is the 'new' keyword in JavaScript?
# 184  What is the 'new' keyword in JavaScript?
# 185  What is the 'new' keyword in JavaScript?
# 186  What is the 'new' keyword in JavaScript?
# 187  What is the 'new' keyword in JavaScript?
# 188  What is the 'new' keyword in JavaScript?
# 189  What is the 'new' keyword in JavaScript?
# 190  What is the 'new' keyword in JavaScript?
# 191  What is the 'new' keyword in JavaScript?
# 192  What is the 'new' keyword in JavaScript?
# 193  What is the 'new' keyword in JavaScript?
# 194  What is the 'new' keyword in JavaScript?
# 195  What is the 'new' keyword in JavaScript?
# 196  What is the 'new' keyword in JavaScript?
# 197  What is the 'new' keyword in JavaScript?
# 198  What is the 'new' keyword in JavaScript?
# 199  What is the 'new' keyword in JavaScript?
# 200  What is the 'new' keyword in JavaScript?
# 201  What is the 'new' keyword in JavaScript?
#
#                                               POSTBODY            POSTDATE  \
# 172  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 173  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 174  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 175  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 176  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 177  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 178  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 179  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 180  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 181  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 182  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 183  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 184  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 185  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 186  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 187  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 188  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 189  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 190  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 191  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 192  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 193  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 194  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 195  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 196  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 197  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 198  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 199  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 200  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
# 201  \n                \n<p>The <code>new</code> ke... 2009-10-29 21:32:45
#
#      POSTVOTECOUNTS         COMMENTID  COMMENTSCORE COMMENTUSERNAME  ...  \
# 172            1912               NaN           NaN             NaN  ...
# 173            1912   comment-1517440          13.0        Chetan S  ...
# 174            1912  comment-94796557           1.0  MartianMartian  ...
# 175            1912               NaN           NaN             NaN  ...
# 176            1912               NaN           NaN             NaN  ...
# 177            1912               NaN           NaN             NaN  ...
# 178            1912               NaN           NaN             NaN  ...
# 179            1912               NaN           NaN             NaN  ...
# 180            1912               NaN           NaN             NaN  ...
# 181            1912               NaN           NaN             NaN  ...
# 182            1912               NaN           NaN             NaN  ...
# 183            1912               NaN           NaN             NaN  ...
# 184            1912               NaN           NaN             NaN  ...
# 185            1912               NaN           NaN             NaN  ...
# 186            1912               NaN           NaN             NaN  ...
# 187            1912               NaN           NaN             NaN  ...
# 188            1912               NaN           NaN             NaN  ...
# 189            1912               NaN           NaN             NaN  ...
# 190            1912               NaN           NaN             NaN  ...
# 191            1912               NaN           NaN             NaN  ...
# 192            1912               NaN           NaN             NaN  ...
# 193            1912               NaN           NaN             NaN  ...
# 194            1912               NaN           NaN             NaN  ...
# 195            1912               NaN           NaN             NaN  ...
# 196            1912               NaN           NaN             NaN  ...
# 197            1912               NaN           NaN             NaN  ...
# 198            1912               NaN           NaN             NaN  ...
# 199            1912               NaN           NaN             NaN  ...
# 200            1912               NaN           NaN             NaN  ...
# 201            1912               NaN           NaN             NaN  ...
#
#          ANSWERCMTDATETIME ANSWERCMTVOTECOUNTS            TYPE   postId  \
# 172                    NaN                 NaN            post  1646698
# 173                    NaN                 NaN    post_comment  1646698
# 174                    NaN                 NaN    post_comment  1646698
# 175                    NaN                 NaN          answer  1646698
# 176  Apr 14, 2011 at 14:55             ('53',)  answer_comment  1646698
# 177  Feb 27, 2012 at 19:05             ('12',)  answer_comment  1646698
# 178  Oct 23, 2012 at 22:36             ('14',)  answer_comment  1646698
# 179    Jun 6, 2013 at 2:04             ('11',)  answer_comment  1646698
# 180  Feb 17, 2014 at 12:18              ('7',)  answer_comment  1646698
# 181                    NaN                 NaN          answer  1646698
# 182  Jan 21, 2013 at 13:24              ('8',)  answer_comment  1646698
# 183  Jul 24, 2013 at 19:20              ('4',)  answer_comment  1646698
# 184  Jul 23, 2016 at 13:22              ('3',)  answer_comment  1646698
# 185  Sep 11, 2017 at 11:47              ('3',)  answer_comment  1646698
# 186  Sep 11, 2017 at 12:00              ('2',)  answer_comment  1646698
# 187                    NaN                 NaN          answer  1646698
# 188  Oct 20, 2013 at 10:11             ('78',)  answer_comment  1646698
# 189   Apr 2, 2014 at 11:12              ('1',)  answer_comment  1646698
# 190  Apr 28, 2014 at 18:19              ('7',)  answer_comment  1646698
# 191   Oct 8, 2015 at 21:40              ('3',)  answer_comment  1646698
# 192   Oct 8, 2015 at 21:53              ('3',)  answer_comment  1646698
# 193                    NaN                 NaN          answer  1646698
# 194   Feb 2, 2017 at 21:26              ('8',)  answer_comment  1646698
# 195   Sep 30, 2022 at 7:39               ('',)  answer_comment  1646698
# 196                    NaN                 NaN          answer  1646698
# 197  Oct 29, 2009 at 21:37              ('8',)  answer_comment  1646698
# 198  Oct 29, 2009 at 21:41              ('2',)  answer_comment  1646698
# 199  Oct 29, 2009 at 21:41             ('12',)  answer_comment  1646698
# 200                    NaN                 NaN          answer  1646698
# 201    Oct 7, 2013 at 7:33              ('9',)  answer_comment  1646698
#
#                                         title partial_ratio token_sort_ratio  \
# 172  What is the 'new' keyword in JavaScript?            50               54
# 173  What is the 'new' keyword in JavaScript?            50               54
# 174  What is the 'new' keyword in JavaScript?            50               54
# 175  What is the 'new' keyword in JavaScript?            50               54
# 176  What is the 'new' keyword in JavaScript?            50               54
# 177  What is the 'new' keyword in JavaScript?            50               54
# 178  What is the 'new' keyword in JavaScript?            50               54
# 179  What is the 'new' keyword in JavaScript?            50               54
# 180  What is the 'new' keyword in JavaScript?            50               54
# 181  What is the 'new' keyword in JavaScript?            50               54
# 182  What is the 'new' keyword in JavaScript?            50               54
# 183  What is the 'new' keyword in JavaScript?            50               54
# 184  What is the 'new' keyword in JavaScript?            50               54
# 185  What is the 'new' keyword in JavaScript?            50               54
# 186  What is the 'new' keyword in JavaScript?            50               54
# 187  What is the 'new' keyword in JavaScript?            50               54
# 188  What is the 'new' keyword in JavaScript?            50               54
# 189  What is the 'new' keyword in JavaScript?            50               54
# 190  What is the 'new' keyword in JavaScript?            50               54
# 191  What is the 'new' keyword in JavaScript?            50               54
# 192  What is the 'new' keyword in JavaScript?            50               54
# 193  What is the 'new' keyword in JavaScript?            50               54
# 194  What is the 'new' keyword in JavaScript?            50               54
# 195  What is the 'new' keyword in JavaScript?            50               54
# 196  What is the 'new' keyword in JavaScript?            50               54
# 197  What is the 'new' keyword in JavaScript?            50               54
# 198  What is the 'new' keyword in JavaScript?            50               54
# 199  What is the 'new' keyword in JavaScript?            50               54
# 200  What is the 'new' keyword in JavaScript?            50               54
# 201  What is the 'new' keyword in JavaScript?            50               54
#
#     token_set_ratio time_score vote_score
# 172              81        1.0  27.548314
# 173              81        1.0  27.548314
# 174              81        1.0  27.548314
# 175              81        1.0  27.548314
# 176              81        1.0  27.548314
# 177              81        1.0  27.548314
# 178              81        1.0  27.548314
# 179              81        1.0  27.548314
# 180              81        1.0  27.548314
# 181              81        1.0  27.548314
# 182              81        1.0  27.548314
# 183              81        1.0  27.548314
# 184              81        1.0  27.548314
# 185              81        1.0  27.548314
# 186              81        1.0  27.548314
# 187              81        1.0  27.548314
# 188              81        1.0  27.548314
# 189              81        1.0  27.548314
# 190              81        1.0  27.548314
# 191              81        1.0  27.548314
# 192              81        1.0  27.548314
# 193              81        1.0  27.548314
# 194              81        1.0  27.548314
# 195              81        1.0  27.548314
# 196              81        1.0  27.548314
# 197              81        1.0  27.548314
# 198              81        1.0  27.548314
# 199              81        1.0  27.548314
# 200              81        1.0  27.548314
# 201              81        1.0  27.548314
#
# [30 rows x 30 columns]
